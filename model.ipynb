# %%
import pandas as pd

# %%
movies_df = pd.read_csv("../input/millions-of-movies/movies.csv")

# %%
movies_df.isnull().sum()
# Out:
# id                           0
# title                        4
# genres                  210787
# original_language            0
# overview                118561
# popularity                   0
# production_companies    385554
# release_date             52360
# budget                       0
# revenue                      0
# runtime                  34441
# status                       0
# tagline                 614611
# vote_average                 0
# vote_count                   0
# credits                 225057
# keywords                512431
# poster_path             185154
# backdrop_path           500151
# recommendations         687977
# dtype: int64

# %%
movies_df.duplicated().sum()
# Out:
# 1

# %%
movies_df.groupby("title").head()
# Out:
#             id                                            title  \
# 0       758323                              The Pope's Exorcist
# 1       667538                 Transformers: Rise of the Beasts
# 2       640146                Ant-Man and the Wasp: Quantumania
# 3       677179                                        Creed III
# 4       502356                      The Super Mario Bros. Movie
# ...        ...                                              ...
# 722735  576855                                    Stastriptease
# 722736  208587                                Halifax v Salford
# 722737  796294                                        Caribbean
# 722738  872952  The Anatomy of a Virus: The Making of Antiviral
# 722739  968161                                    Gising Sining
#
#                                            genres original_language  \
# 0                         Horror-Mystery-Thriller                en
# ...

# %%
movies_df = movies_df[["title","genres","original_language","vote_average","vote_count","release_date"]]
movies_df = movies_df.rename(columns={"original_language":"language"})

# %%
movies_df = movies_df[movies_df["vote_count"]>=2500].sort_values("vote_average",ascending=False)
movies_df.head(100)
# Out:
#                             title                      genres language  \
# 365                 The Godfather                 Drama-Crime       en
# 508      The Shawshank Redemption                 Drama-Crime       en
# 1057             Schindler's List           Drama-History-War       en
# 966         The Godfather Part II                 Drama-Crime       en
# 2468  Dilwale Dulhania Le Jayenge        Comedy-Drama-Romance       hi
# ...                           ...                         ...      ...
# 2131           Memories of Murder        Crime-Drama-Thriller       ko
# 6279          There Will Be Blood                       Drama       en
# 5731             Some Like It Hot  Comedy-Music-Romance-Crime       en
# 4445             The Elephant Man               Drama-History       en
# 1286            Pride & Prejudice               Drama-Romance       en
#
#       vote_average  vote_count release_date
# 365          8.710     18149.0   1972-03-14
# ...

# %%
len(str(17/4))
# Out:
# 4
